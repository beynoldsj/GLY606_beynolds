# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
twodee = np.array([[2,2,2,2],
                   [3,3,3,3],
                   [7,1,1,1]])

twodee
# Out:
# array([[2, 2, 2, 2],
#        [3, 3, 3, 3],
#        [7, 1, 1, 1]])

# %%
twodee[0,3]
# Out:
# 2

# %%
twodee[:,0]
# Out:
# array([2, 3, 7])

# %%
twodee[0,:]
# Out:
# array([2, 2, 2, 2])

# %%
twodee0 = twodee
twodee1 = np.array([[1,1,1,1],
                   [4,4,4,4],
                   [8,6,6,6]])

# %%
threedee = np.array([twodee0, twodee1])
threedee
# Out:
# array([[[2, 2, 2, 2],
#         [3, 3, 3, 3],
#         [7, 1, 1, 1]],
#
#        [[1, 1, 1, 1],
#         [4, 4, 4, 4],
#         [8, 6, 6, 6]]])

# %%
threedee[0][2][0]
# Out:
# 7

# %%
threedee[1][2][0]
# Out:
# 8

# %%
# get the dimensions
threedee.shape
# Out:
# (2, 3, 4)

# %%
import xarray as xr

# %%
data = xr.DataArray(np.random.randn(2,3), dims=("x","y"), coords={"x": [10,20]})
coords = {"x": [10,20]}

# %%
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.65430569, -0.30758892, -0.83532872],
#        [-1.21942751, -1.37807313, -0.54624659]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %%
data.values
# Out:
# array([[ 0.65430569, -0.30758892, -0.83532872],
#        [-1.21942751, -1.37807313, -0.54624659]])

# %%
data.dims
# Out:
# ('x', 'y')

# %%
data.coords
# Out:
# Coordinates:
#   * x        (x) int64 10 20

# %%
data.attrs
# Out:
# {}

# %%
# typical indexing like numpy
data[0,:]
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.65430569, -0.30758892, -0.83532872])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %%
# same as pandas: positional and coord label
data.loc[10]
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.65430569, -0.30758892, -0.83532872])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %%
# isel or "integer select" by dimension and integer label
data.isel(x=0)
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.65430569, -0.30758892, -0.83532872])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %%
# sel or "select" by dimension name and coordinate label
data.sel(x=10)
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.65430569, -0.30758892, -0.83532872])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %%
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.65430569, -0.30758892, -0.83532872],
#        [-1.21942751, -1.37807313, -0.54624659]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %%
data.attrs["long_name"] = "random velocity"
data.attrs["units"] = "metres/sec"
data.attrs["description"] = "It's a random variable yo"

# %%
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.65430569, -0.30758892, -0.83532872],
#        [-1.21942751, -1.37807313, -0.54624659]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:    random velocity
#     units:        metres/sec
#     description:  It's a random variable yo

# %%
data+10 # adds 10 to all vals
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[10.65430569,  9.69241108,  9.16467128],
#        [ 8.78057249,  8.62192687,  9.45375341]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %%
np.sin(data) # looks like it taks sine of all vals
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.60860848, -0.3027616 , -0.7415171 ],
#        [-0.93890247, -0.98148629, -0.51948368]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:    random velocity
#     units:        metres/sec
#     description:  It's a random variable yo

# %%
data.T # this must be a built in matix transpose
# Out:
# <xarray.DataArray (y: 3, x: 2)>
# array([[ 0.65430569, -1.21942751],
#        [-0.30758892, -1.37807313],
#        [-0.83532872, -0.54624659]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:    random velocity
#     units:        metres/sec
#     description:  It's a random variable yo

# %%
data.sum() # hmm i wonder what this does
# Out:
# <xarray.DataArray ()>
# array(-3.63235919)

# %%
data.mean(dim="x") # looks like it averages all x values for each y value
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.28256091, -0.84283103, -0.69078766])
# Dimensions without coordinates: y

# %%
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.65430569, -0.30758892, -0.83532872],
#        [-1.21942751, -1.37807313, -0.54624659]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:    random velocity
#     units:        metres/sec
#     description:  It's a random variable yo

# %%
data.plot()

# %%
fig,ax1 = subplots()
data.plot(ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_265/3108386986.py in <module>
# ----> 1 fig,ax1 = subplots()
#       2 data.plot(ax=ax1)
#
# NameError: name 'subplots' is not defined
