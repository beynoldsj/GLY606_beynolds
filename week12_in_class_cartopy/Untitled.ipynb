# %%
import matplotlib.pyplot as plt
import numpy as np
import cartopy
import cartopy.crs as ccrs
from cartopy import config
import xarray as xr
import os

# %%
# Plot a set of axes with a plate carree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# plot the coastlines! use zorder to define layer it wis plotted on
ax.coastlines(zorder=0)

# Add land! We have the ability to change the face and edge colors of the land
ax.add_feature(cartopy.feature.LAND,facecolor='black',edgecolor='white',zorder=1)

## Change the spatial extent that we see on our map
ax.set_extent([-100, -50, 15, 60], crs=ccrs.PlateCarree())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /apps/share64/debian10/anaconda/anaconda-7/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /apps/share64/debian10/anaconda/anaconda-7/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1255         """Send a complete request to the server."""
# -> 1256         self._send_request(method, url, body, headers, encode_chunked)
#    1257
#
# /apps/share64/debian10/anaconda/anaconda-7/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1301             body = _encode(body, 'body')
# ...
